# %% [markdown]
# ## Instalation des depandances.

# %%
# ! pip install transformers

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
import transformers
import torch
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertModel, BertConfig

# %% [markdown]
# ### Bert Tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case = True)

# %%
MAX_LEN = 50
TRAIN_BATCH_SIZE = 8
VALID_BATCH_SIZE = 4
EPOCHS = 1
LEARNING_RATE = 1e-05

# %% [markdown]
# ## Les Donnees

# %%
train_data_path = "./Version 1/data/data_questions/questions-train.txt"
test_data_path =  "./Version 1/data/data_questions/questions-test.txt"

# %% [markdown]
# ### Les classes de nos questions

# %%
classes = {
     'ABBREVIATION': 0,
     'DEFINITION': 1,
     'DESCRIPTION': 2,
     'ENTITY': 3,
     'LOCATION': 4,
     'ORGANIZATION': 5,
     'PERSON': 6,
     'QUANTITY': 7,
     'TEMPORAL': 8
}

# %%
def get_data(datapath):
    X = []
    Y = []
    with open(datapath, 'r') as file:
        lines = file.readlines()
        for line in lines:
            splited_line = line.split(" ")
            Y.append(classes[splited_line[0]])
            X.append(" ".join(splited_line[1:]))
    return X , Y

# %%
X , Y = get_data(train_data_path)
sentences = [tokenizer.tokenize(sentence) for sentence in X]

# %% [markdown]
# #### Trouver la taille de la question la plus long

# %%
# sentence_max_length = 0 

# for sentence in sentences:
#     sentence_max_len = max(sentence_max_len, len(sentence))

# %%
# def mask_inputs_for_bert(sentences ,sentence_max_length):
#     # Tokenize all of the sentences and map the tokens to thier word IDs.
#     input_ids = []
#     attention_masks = []
#     i = 0 
#     for sentence in sentences:
#         # “encode_plus* will:
#         # (1) Tokenize the sentence.
#         # (2) Prepend the “[CLS]" token to the start.
#         # (3) Append the “[SEP]* token to the end.
#         # (4) Map tokens to their IDs.
#         # (5) Pad or truncate the sentence to ‘max_length*while i < len(sentence):
#         # (6) Create attention masks for [PAD] tokens.

#         if(i<3):
#             print("Question", sentence)

#             encoded_dict = tokenizer.encode_plus(
#                             sentence, # Sentence to encode.
#                             add_special_tokens = True, # Add ‘[CLS]' and '[SEP]’
#                             max_length = sentence_max_len, # Pad & truncate all sentences.
#                             pad_to_max_length = True,
#                             return_attention_mask = True, # Construct attn. masks.
#                             )
#         if(i<3):

#             print("dict",encoded_dict['input_ids'])
#             # Add the encoded sentence to the list.

#             input_ids.append(encoded_dict['input_ids'])

#             # and its attention mask (simply differentiates padding from non-padding).
#             attention_masks.append(encoded_dict['attention_mask'])

#             i = i+1

#     #         convert to tensor and return

#             input_ids = torch.tensor(input_ids)
#             attention_masks = torch.tensor(attention_masks)
#             return input_ids,attention_masks

# %%
# X_train, train_mask = mask_inputs_for_bert(X , sentence_max_length)# In[ ]:def test_get_all_by_host_with_pool(self):
# y_train = torch.tensor(Y)

# %%
# bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels = 2)

# %%
# loss = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(params =  bert_model.parameters(), lr=1e-05)

# %%
# bert_model.compile(loss=loss, optimizer=optimizer)

# %%
# def loss_fn(outputs, targets):
#     return torch.nn.BCEWithLogitsLoss()(outputs, targets)

# %%
# optimizer = torch.optim.Adam(params =  bert_model.parameters(), lr=1e-05)

# %%
# def train(epoch):
#     bert_model.train()
#     for _,data in enumerate(training_loader, 0):
#         ids = data['ids'].to(device, dtype = torch.long)
#         mask = data['mask'].to(device, dtype = torch.long)
#         token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
#         targets = data['targets'].to(device, dtype = torch.float)

#         outputs = model(ids, mask, token_type_ids)

#         optimizer.zero_grad()
#         loss = loss_fn(outputs, targets)
#         if _%5000==0:
#             print(f'Epoch: {epoch}, Loss:  {loss.item()}')
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

# %%
class CustomDataset(Dataset):

    def __init__(self, X, y, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.sentences = X
        self.targets = y
        self.max_len = max_len

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, index):
        question = self.sentences[index]
        inputs = self.tokenizer.encode_plus(
            question,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]


        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'targets': torch.tensor(self.targets[index], dtype=torch.float)
        }

# %%
training_set = CustomDataset(X, Y, tokenizer, MAX_LEN)

# %%
training_set.

# %%
# Out:
# [['how', 'far', 'is', 'it', 'from', 'denver', 'to', 'aspen', '?'],
#  ['what', 'county', 'is', 'modest', '##o', ',', 'california', 'in', '?'],
#  ['who', 'was', 'galileo', '?'],
#  ['what', 'is', 'an', 'atom', '?'],
#  ['when', 'did', 'hawaii', 'become', 'a', 'state', '?'],
#  ['how', 'tall', 'is', 'the', 'sears', 'building', '?'],
#  ['why', 'does', 'the', 'moon', 'turn', 'orange', '?'],
#  ['what', 'is', 'autism', '?'],
#  ['what', 'city', 'had', 'a', 'world', 'fair', 'in', '1900', '?'],
#  ['what', 'person', "'", 's', 'head', 'is', 'on', 'a', 'dime', '?'],
#  ['what',
#   'is',
#   'the',
#   'average',
#   'weight',
#   'of',
#   'a',
#   'yellow',
#   'labrador',
#   '?'],
#  ['who',
#   'was',
#   'the',
#   'first',
#   'man',
#   'to',
#   'fly',
#   'across',
#   'the',
#   'pacific',
#   'ocean',
#   '?'],
#  ['when', 'did', 'idaho', 'become', 'a', 'state', '?'],
#  ['what',
#   'is',
#   'the',
#   'life',
#   'expect',
#   '##ancy',
#   'for',
#   'cricket',
#   '##s',
#   '?'],
#  ['who',
#   'developed',
#   'the',
#   'va',
#   '##cci',
#   '##nation',
#   'against',
#   'pol',
#   '##io',
#   '?'],
#  ['what', 'is', 'ep', '##ile', '##psy', '?'],
#  ['what', 'year', 'did', 'the', 'titanic', 'sink', '?'],
#  ['who', 'was', 'the', 'first', 'american', 'to', 'walk', 'in', 'space', '?'],
#  ['what', 'is', 'a', 'bio', '##sphere', '?'],
#  ['what',
#   'river',
#   'in',
#   'the',
#   'us',
#   'is',
#   'known',
#   'as',
#   'the',
#   'big',
#   'muddy',
#   '?'],
#  ['what', 'is', 'bipolar', 'disorder', '?'],
#  ['what', 'is', 'cho', '##les', '##terol', '?'],
#  ['who', 'developed', 'the', 'macintosh', 'computer', '?'],
#  ['what', 'is', 'caf', '##fe', '##ine', '?'],
#  ['what',
#   'imaginary',
#   'line',
#   'is',
#   'halfway',
#   'between',
#   'the',
#   'north',
#   'and',
#   'south',
#   'poles',
#   '?'],
#  ['where', 'is', 'john', 'wayne', 'airport', '?'],
#  ['what', 'hemisphere', 'is', 'the', 'philippines', 'in', '?'],
#  ['what',
#   'is',
#   'the',
#   'average',
#   'speed',
#   'of',
#   'the',
#   'horses',
#   'at',
#   'the',
#   'kentucky',
#   'derby',
#   '?'],
#  ['where', 'are', 'the', 'rocky', 'mountains', '?'],
#  ['what', 'are', 'invertebrates', '?'],
#  ['what',
#   'is',
#   'the',
#   'temperature',
#   'at',
#   'the',
#   'center',
#   'of',
#   'the',
#   'earth',
#   '?'],
#  ['when',
#   'did',
#   'john',
#   'f',
#   '.',
#   'kennedy',
#   'get',
#   'elected',
#   'as',
#   'president',
#   '?'],
#  ['how', 'old', 'was', 'elvis', 'presley', 'when', 'he', 'died', '?'],
#  ['where', 'is', 'the', 'or', '##ino', '##co', 'river', '?'],
#  ['how',
#   'far',
#   'is',
#   'the',
#   'service',
#   'line',
#   'from',
#   'the',
#   'net',
#   'in',
#   'tennis',
#   '?'],
#  ['how', 'much', 'fiber', 'should', 'you', 'have', 'per', 'day', '?'],
#  ['how', 'many', 'great', 'lakes', 'are', 'there', '?'],
#  ['what', 'is', 'te', '##fl', '##on', '?'],
#  ['what', 'is', 'ami', '##trip', '##ty', '##line', '?'],
#  ['what', 'is', 'a', 'shaman', '?'],
#  ['how', 'long', 'did', 'rip', 'van', 'wink', '##le', 'sleep', '?'],
#  ['what', 'are', 'tri', '##gly', '##cer', '##ides', '?'],
#  ['how', 'many', 'liter', '##s', 'in', 'a', 'gallon', '?'],
#  ['what', 'are', 'amp', '##hi', '##bians', '?'],
#  ['who', 'discovered', 'x', '-', 'rays', '?'],
#  ['which',
#   'comedian',
#   "'",
#   's',
#   'signature',
#   'line',
#   'is',
#   '`',
#   '`',
#   'can',
#   'we',
#   'talk',
#   "'",
#   "'",
#   '?'],
#  ['what', 'is', 'fi', '##bro', '##my', '##al', '##gia', '?'],
#  ['what', 'is', 'done', 'with', 'worn', 'or', 'outdated', 'flags', '?'],
#  ['what', 'does', 'cc', 'in', 'engines', 'mean', '?'],
#  ['when', 'did', 'elvis', 'presley', 'die', '?'],
#  ['what', 'is', 'the', 'capital', 'of', 'yugoslavia', '?'],
#  ['where', 'is', 'milan', '?'],
#  ['what', 'is', 'the', 'speed', 'humming', '##birds', 'fly', '?'],
#  ['what', 'is', 'the', 'oldest', 'city', 'in', 'the', 'united', 'states', '?'],
#  ['what', 'was', 'w', '.', 'c', '.', 'fields', "'", 'real', 'name', '?'],
#  ['what',
#   'river',
#   'flows',
#   'between',
#   'fargo',
#   ',',
#   'north',
#   'dakota',
#   'and',
#   'moor',
#   '##head',
#   ',',
#   'minnesota',
#   '?'],
#  ['what',
#   'state',
#   'did',
#   'the',
#   'battle',
#   'of',
#   'big',
#   '##horn',
#   'take',
#   'place',
#   'in',
#   '?'],
#  ['who', 'was', 'abraham', 'lincoln', '?'],
#  ['what', 'are', 'spider', 'veins', '?'],
#  ['what', 'day', 'and', 'month', 'did', 'john', 'lennon', 'die', '?'],
#  ['what', 'strait', 'separates', 'north', 'america', 'from', 'asia', '?'],
#  ['what', 'is', 'the', 'population', 'of', 'seattle', '?'],
#  ['how', 'much', 'was', 'a', 'ticket', 'for', 'the', 'titanic', '?'],
#  ['what', 'is', 'the', 'largest', 'city', 'in', 'the', 'world', '?'],
#  ['what',
#   'american',
#   'composer',
#   'wrote',
#   'the',
#   'music',
#   'for',
#   '`',
#   '`',
#   'west',
#   'side',
#   'story',
#   "'",
#   "'",
#   '?'],
#  ['where', 'is', 'the', 'mall', 'of', 'the', 'america', '?'],
#  ['what', 'is', 'the', 'ph', 'scale', '?'],
#  ['how',
#   'tall',
#   'is',
#   'the',
#   'gateway',
#   'arch',
#   'in',
#   'st',
#   '.',
#   'louis',
#   ',',
#   'mo',
#   '?'],
#  ['how',
#   'much',
#   'does',
#   'the',
#   'human',
#   'adult',
#   'female',
#   'brain',
#   'weigh',
#   '?'],
#  ['who', 'was', 'the', 'first', 'governor', 'of', 'alaska', '?'],
#  ['what', 'is', 'a', 'prism', '?'],
#  ['when', 'was', 'the', 'first', 'liver', 'transplant', '?'],
#  ['who',
#   'was',
#   'elected',
#   'president',
#   'of',
#   'south',
#   'africa',
#   'in',
#   '1994',
#   '?'],
#  ['what', 'is', 'the', 'population', 'of', 'china', '?'],
#  ['when', 'was', 'rosa', 'parks', 'born', '?'],
#  ['why', 'is', 'a', 'lady', '##bu', '##g', 'helpful', '?'],
#  ['what', 'is', 'am', '##ox', '##ici', '##llin', '?'],
#  ['who',
#   'was',
#   'the',
#   'first',
#   'female',
#   'united',
#   'states',
#   'representative',
#   '?'],
#  ['what', 'are', 'x', '##ero', '##phy', '##tes', '?'],
#  ['what', 'country', 'did', 'ponce', 'de', 'leon', 'come', 'from', '?'],
#  ['what', 'is', 'desktop', 'publishing', '?'],
#  ['what',
#   'is',
#   'the',
#   'temperature',
#   'of',
#   'the',
#   'sun',
#   "'",
#   's',
#   'surface',
#   '?'],
#  ['what', 'year', 'did', 'canada', 'join', 'the', 'united', 'nations', '?'],
#  ['where', 'is', 'prince', 'edward', 'island', '?'],
#  ['mercury', ',', 'what', 'year', 'was', 'it', 'discovered', '?'],
#  ['what', 'is', 'cry', '##ogenic', '##s', '?'],
#  ['what', 'are', 'coral', 'reefs', '?'],
#  ['what', 'is', 'ne', '##uro', '##logy', '?'],
#  ['who', 'invented', 'the', 'cal', '##cula', '##tor', '?'],
#  ['how', 'do', 'you', 'measure', 'earthquakes', '?'],
#  ['who', 'is', 'duke', 'ellington', '?'],
#  ['what', 'county', 'is', 'phoenix', ',', 'az', 'in', '?'],
#  ['what', 'is', 'a', 'micro', '##n', '?'],
#  ['the',
#   'sun',
#   "'",
#   's',
#   'core',
#   ',',
#   'what',
#   'is',
#   'the',
#   'temperature',
#   '?'],
#  ['when', 'were', 'william', 'shakespeare', "'", 's', 'twins', 'born', '?'],
#  ['what', 'is', 'the', 'highest', 'dam', 'in', 'the', 'u', '.', 's', '.', '?'],
#  ['what', 'is', 'ac', '##up', '##un', '##cture', '?'],
#  ['what',
#   'is',
#   'the',
#   'length',
#   'of',
#   'the',
#   'coastline',
#   'of',
#   'the',
#   'state',
#   'of',
#   'alaska',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'name',
#   'of',
#   'neil',
#   'armstrong',
#   "'",
#   's',
#   'wife',
#   '?'],
#  ['who', 'won', 'ms', '.', 'american', 'in', '1989', '?'],
#  ['when', 'did', 'the', 'hind', '##enberg', 'crash', '?'],
#  ['what',
#   'was',
#   'the',
#   'last',
#   'year',
#   'that',
#   'the',
#   'chicago',
#   'cubs',
#   'won',
#   'the',
#   'world',
#   'series',
#   '?'],
#  ['where', 'is', 'perth', '?'],
#  ['what', 'year', 'did', 'wwii', 'begin', '?'],
#  ['how',
#   'did',
#   'ser',
#   '##f',
#   '##dom',
#   'develop',
#   'in',
#   'and',
#   'then',
#   'leave',
#   'russia',
#   '?'],
#  ['what',
#   'films',
#   'featured',
#   'the',
#   'character',
#   'pope',
#   '##ye',
#   'doyle',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'find',
#   'a',
#   'list',
#   'of',
#   'celebrities',
#   "'",
#   'real',
#   'names',
#   '?'],
#  ['what',
#   'f',
#   '##ow',
#   '##l',
#   'grabs',
#   'the',
#   'spotlight',
#   'after',
#   'the',
#   'chinese',
#   'year',
#   'of',
#   'the',
#   'monkey',
#   '?'],
#  ['what', 'is', 'the', 'full', 'form', 'of', '.', 'com', '?'],
#  ['what',
#   'contempt',
#   '##ible',
#   'sc',
#   '##ound',
#   '##rel',
#   'stole',
#   'the',
#   'cork',
#   'from',
#   'my',
#   'lunch',
#   '?'],
#  ['what',
#   'team',
#   'did',
#   'baseball',
#   "'",
#   's',
#   'st',
#   '.',
#   'louis',
#   'browns',
#   'become',
#   '?'],
#  ['what', 'is', 'the', 'oldest', 'profession', '?'],
#  ['what', 'are', 'liver', 'enzymes', '?'],
#  ['name',
#   'the',
#   'scar',
#   '-',
#   'faced',
#   'bounty',
#   'hunter',
#   'of',
#   'the',
#   'old',
#   'west',
#   '.'],
#  ['when', 'was', 'oz', '##zy', 'os', '##bourne', 'born', '?'],
#  ['why', 'do', 'heavier', 'objects', 'travel', 'downhill', 'faster', '?'],
#  ['who', 'was', 'the', 'pride', 'of', 'the', 'yankees', '?'],
#  ['who', 'killed', 'gandhi', '?'],
#  ['what',
#   'is',
#   'considered',
#   'the',
#   'cost',
#   '##liest',
#   'disaster',
#   'the',
#   'insurance',
#   'industry',
#   'has',
#   'ever',
#   'faced',
#   '?'],
#  ['what',
#   'sprawling',
#   'u',
#   '.',
#   's',
#   '.',
#   'state',
#   'boasts',
#   'the',
#   'most',
#   'airports',
#   '?'],
#  ['what',
#   'did',
#   'the',
#   'only',
#   'repealed',
#   'amendment',
#   'to',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'constitution',
#   'deal',
#   'with',
#   '?'],
#  ['how',
#   'many',
#   'jews',
#   'were',
#   'executed',
#   'in',
#   'concentration',
#   'camps',
#   'during',
#   'wwii',
#   '?'],
#  ['what', 'is', '`', '`', 'nine', 'inch', 'nails', "'", "'", '?'],
#  ['what', 'is', 'an', 'ann', '##ota', '##ted', 'bibliography', '?'],
#  ['what', 'is', 'the', 'date', 'of', 'boxing', 'day', '?'],
#  ['what',
#   'articles',
#   'of',
#   'clothing',
#   'are',
#   'token',
#   '##s',
#   'in',
#   'monopoly',
#   '?'],
#  ['name', '11', 'famous', 'martyrs', '.'],
#  ['what', "'", 's', 'the', 'olympic', 'motto', '?'],
#  ['what',
#   'is',
#   'the',
#   'origin',
#   'of',
#   'the',
#   'name',
#   '`',
#   'scarlett',
#   "'",
#   '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'second',
#   '-',
#   'most',
#   '-',
#   'used',
#   'vowel',
#   'in',
#   'english',
#   '?'],
#  ['who', 'was', 'the', 'inventor', 'of', 'silly', 'put', '##ty', '?'],
#  ['what',
#   'is',
#   'the',
#   'highest',
#   'waterfall',
#   'in',
#   'the',
#   'united',
#   'states',
#   '?'],
#  ['name', 'a', 'golf', 'course', 'in', 'myrtle', 'beach', '.'],
#  ['which', 'two', 'states', 'en', '##cl', '##ose', 'chesapeake', 'bay', '?'],
#  ['what', 'does', 'the', 'abbreviation', 'aids', 'stand', 'for', '?'],
#  ['what', 'does', 'a', 'sperm', '##olo', '##ger', 'collect', '?'],
#  ['how',
#   'many',
#   'points',
#   'make',
#   'up',
#   'a',
#   'perfect',
#   'five',
#   '##pin',
#   'bowling',
#   'score',
#   '?'],
#  ['which',
#   'company',
#   'that',
#   'manufactures',
#   'video',
#   '-',
#   'game',
#   'hardware',
#   'sells',
#   'the',
#   '`',
#   '`',
#   'super',
#   'system',
#   "'",
#   "'",
#   '?'],
#  ['how',
#   'many',
#   'community',
#   'chest',
#   'cards',
#   'are',
#   'there',
#   'in',
#   'monopoly',
#   '?'],
#  ['what', 'do', 'mormon', '##s', 'believe', '?'],
#  ['when', 'did', 'the', 'ne', '##ander', '##thal', 'man', 'live', '?'],
#  ['in', 'what', 'religion', 'was', 'isis', 'the', 'nature', 'goddess', '?'],
#  ['where',
#   'do',
#   'the',
#   'adventures',
#   'of',
#   '`',
#   '`',
#   'the',
#   'swiss',
#   'family',
#   'robinson',
#   "'",
#   "'",
#   'take',
#   'place',
#   '?'],
#  ['what',
#   'relative',
#   'of',
#   'the',
#   'ra',
#   '##co',
#   '##on',
#   'is',
#   'sometimes',
#   'known',
#   'as',
#   'the',
#   'cat',
#   '-',
#   'bear',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'register',
#   'my',
#   'website',
#   'in',
#   'yahoo',
#   'for',
#   'free',
#   '?'],
#  ['what',
#   'was',
#   'cash',
#   '-',
#   'conscious',
#   'colonel',
#   'edwin',
#   'l',
#   '.',
#   'drake',
#   'the',
#   'first',
#   'to',
#   'drill',
#   '?'],
#  ['how', 'many', 'people', 'in', 'the', 'world', 'speak', 'french', '?'],
#  ['how',
#   'many',
#   'inches',
#   'over',
#   'six',
#   'feet',
#   'is',
#   'the',
#   'venus',
#   'de',
#   'milo',
#   '?'],
#  ['how',
#   'do',
#   'they',
#   'find',
#   'or',
#   'choose',
#   'witnesses',
#   'to',
#   'an',
#   'execution',
#   '?'],
#  ['what',
#   '1920s',
#   'cowboy',
#   'star',
#   'rode',
#   'tony',
#   'the',
#   'wonder',
#   'horse',
#   '?'],
#  ['what',
#   'cocktail',
#   'inspired',
#   'john',
#   'do',
#   '##xa',
#   '##t',
#   'to',
#   'write',
#   'the',
#   'book',
#   'stirred',
#   '-',
#   'not',
#   'shaken',
#   '?'],
#  ['what', 'is', '##ps', 'exist', 'in', 'the', 'caribbean', '?'],
#  ['how',
#   'do',
#   'you',
#   'ask',
#   'a',
#   'total',
#   'stranger',
#   'out',
#   'on',
#   'a',
#   'date',
#   '?'],
#  ['what',
#   'weapon',
#   'is',
#   'the',
#   'mythological',
#   'character',
#   'apollo',
#   'most',
#   'proficient',
#   'with',
#   '?'],
#  ['what',
#   'country',
#   'do',
#   'the',
#   'gala',
#   '##pa',
#   '##gos',
#   'islands',
#   'belong',
#   'to',
#   '?'],
#  ['what', 'is', 'et', '##hol', '##ogy', '?'],
#  ['who', 'was', 'the', 'prophet', 'of', 'the', 'muslim', 'people', '?'],
#  ['where',
#   'did',
#   'the',
#   'term',
#   '`',
#   '`',
#   '86',
#   '##ed',
#   "'",
#   "'",
#   'come',
#   'from',
#   '?'],
#  ['who', 'is', 'snoop', '##y', "'", 's', 'arch', '-', 'enemy', '?'],
#  ['what', 'is', 'the', 'nature', 'of', 'learning', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'only',
#   'color',
#   'johnny',
#   'cash',
#   'wears',
#   'on',
#   'stage',
#   '?'],
#  ['what', "'", 's', 'the', 'term', 'for', 'a', 'young', 'fox', '?'],
#  ['what', 'u', '.', 's', '.', 'state', 'lived', 'under', 'six', 'flags', '?'],
#  ['what', 'is', 'the', 'kashmir', 'issue', '?'],
#  ['where', 'is', 'the', 'loop', '?'],
#  ['what',
#   'does',
#   '`',
#   '`',
#   'extended',
#   'definition',
#   "'",
#   "'",
#   'mean',
#   'and',
#   'how',
#   'would',
#   'one',
#   'write',
#   'a',
#   'paper',
#   'on',
#   'it',
#   '?'],
#  ['what', 'country', "'", 's', 'capital', 'is', 'tirana', '?'],
#  ['what', 'is', 'titanium', '?'],
#  ['who',
#   'do',
#   'herb',
#   'and',
#   'too',
#   '##ts',
#   '##ie',
#   'live',
#   'next',
#   'door',
#   'to',
#   '?'],
#  ['which',
#   'city',
#   'has',
#   'the',
#   'oldest',
#   'relationship',
#   'as',
#   'a',
#   'sister',
#   '##i',
#   '##£',
#   '¿',
#   'city',
#   'with',
#   'los',
#   'angeles',
#   '?'],
#  ['what', 'is', 'a', 'calder', '##a', '?'],
#  ['why', 'do', 'people', 'get', 'call', '##uses', '?'],
#  ['what',
#   'are',
#   'the',
#   'names',
#   'of',
#   'the',
#   'tourist',
#   'attractions',
#   'in',
#   'rei',
#   '##ms',
#   '?'],
#  ['what',
#   'are',
#   'cu',
#   '##sh',
#   '##man',
#   'and',
#   'wakefield',
#   'known',
#   'for',
#   '?'],
#  ['what',
#   'body',
#   'of',
#   'water',
#   'does',
#   'the',
#   'danube',
#   'river',
#   'flow',
#   'into',
#   '?'],
#  ['who', 'is', 'the', 'founder', 'of', 'scientology', '?'],
#  ['what',
#   'does',
#   'the',
#   'six',
#   '-',
#   'footed',
#   'mu',
#   '##sca',
#   'domestic',
#   '##a',
#   'become',
#   'when',
#   'it',
#   'enters',
#   'a',
#   'house',
#   '?'],
#  ['what', 'is', 'the', 'history', 'of', 'skate', '##boarding', '?'],
#  ['who',
#   'starred',
#   'in',
#   'singing',
#   'in',
#   'the',
#   'rain',
#   'and',
#   'the',
#   'singing',
#   'nun',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'make',
#   'fuel',
#   'bricks',
#   'from',
#   'recycled',
#   'newspaper',
#   '?'],
#  ['what',
#   '19th',
#   '-',
#   'century',
#   'painter',
#   'died',
#   'in',
#   'the',
#   'mar',
#   '##ques',
#   '##as',
#   'islands',
#   '?'],
#  ['the',
#   'corpus',
#   'call',
#   '##os',
#   '##um',
#   'is',
#   'in',
#   'what',
#   'part',
#   'of',
#   'the',
#   'body',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'log',
#   'on',
#   'to',
#   'home',
#   'page',
#   'at',
#   'headquarters',
#   'u',
#   '.',
#   's',
#   '.',
#   'european',
#   'command',
#   '?'],
#  ['what',
#   'country',
#   'did',
#   'the',
#   'nazis',
#   'occupy',
#   'for',
#   '1',
#   ',',
#   'cd',
#   'n',
#   '##ns',
#   'in',
#   'n',
#   '##np',
#   'n',
#   '##np',
#   'n',
#   '##np',
#   '.'],
#  ['what', 'is', 'nebraska', "'", 's', 'most', 'valuable', 'resource', '?'],
#  ['how',
#   'many',
#   'species',
#   'of',
#   'the',
#   'great',
#   'white',
#   'shark',
#   'are',
#   'there',
#   '?'],
#  ['what', 'is', 'the', 'origin', 'of', 'head', 'li', '##ce', '?'],
#  ['what',
#   'is',
#   'the',
#   'nickname',
#   'for',
#   'the',
#   'state',
#   'of',
#   'mississippi',
#   '?'],
#  ['what', 'was', 'the', 'first', 'domestic', '##ated', 'bird', '?'],
#  ['how',
#   'many',
#   'vi',
#   '##lli',
#   'are',
#   'found',
#   'in',
#   'the',
#   'small',
#   'int',
#   '##est',
#   '##ine',
#   '?'],
#  ['what', 'country', 'did', 'king', 'wen', '##ces', '##las', 'rule', '?'],
#  ['what', 'is', 'a', 'fear', 'of', 'shadows', '?'],
#  ['who', 'were', 'the', 'five', 'marx', 'brothers', '?'],
#  ['in',
#   'which',
#   'year',
#   'was',
#   'new',
#   'zealand',
#   'excluded',
#   'from',
#   'the',
#   'an',
#   '##zu',
#   '##s',
#   'alliance',
#   '?'],
#  ['when', 'did', 'cnn', 'begin', 'broadcasting', '?'],
#  ['what',
#   'causes',
#   'the',
#   'body',
#   'to',
#   'shiver',
#   'in',
#   'cold',
#   'temperatures',
#   '?'],
#  ['what', 'are', 'bear', 'and', 'bull', 'markets', '?'],
#  ['what',
#   'j',
#   '.',
#   'r',
#   '.',
#   'r',
#   '.',
#   'tolkien',
#   'book',
#   'features',
#   'bi',
#   '##lb',
#   '##o',
#   'bag',
#   '##gins',
#   'as',
#   'the',
#   'central',
#   'character',
#   '?'],
#  ['what', 'is', '`', '`', 'dew', 'point', "'", "'", '?'],
#  ['what', 'is', 'the', 'meaning', 'of', 'jesus', '?'],
#  ['what',
#   'company',
#   "'",
#   's',
#   'logo',
#   'is',
#   'a',
#   '`',
#   '`',
#   'w',
#   "'",
#   "'",
#   'in',
#   'a',
#   'circle',
#   '?'],
#  ['what', 'is', 'the', 'definition', 'of', 'a', 'cascade', '?'],
#  ['when',
#   'did',
#   'roc',
#   '##oco',
#   'painting',
#   'and',
#   'architecture',
#   'flourish',
#   '?'],
#  ['what',
#   'country',
#   "'",
#   's',
#   'national',
#   'passenger',
#   'rail',
#   'system',
#   'is',
#   'called',
#   'via',
#   '?'],
#  ['who', 'invented', 'make', '-', 'up', '?'],
#  ['what',
#   'is',
#   'the',
#   'origin',
#   'of',
#   'the',
#   'word',
#   '`',
#   '`',
#   'attic',
#   "'",
#   "'",
#   '?'],
#  ['what', 'did', 'delilah', 'do', 'to', 'samson', "'", 's', 'hair', '?'],
#  ['what',
#   'kind',
#   'of',
#   'animals',
#   'were',
#   'in',
#   'the',
#   'pale',
#   '##oz',
#   '##oic',
#   'era',
#   '?'],
#  ['which', 'of', 'the', 'following', 'was', 'rhodes', 'scholar', '?'],
#  ['who',
#   'comprised',
#   'the',
#   'now',
#   '-',
#   'defunct',
#   'comic',
#   'book',
#   'team',
#   'known',
#   'as',
#   'the',
#   'champions',
#   '?'],
#  ['how', 'do', 'you', 'make', 'a', 'paint', '##ball', '?'],
#  ['what', 'u', '.', 's', '.', 'state', 'is', 'fort', 'knox', 'in', '?'],
#  ['what', 'is', 'a', 'female', 'rabbit', 'called', '?'],
#  ['where', 'is', 'the', 'highest', 'point', 'in', 'japan', '?'],
#  ['where', 'do', 'chihuahua', '##s', 'come', 'from', '?'],
#  ['where',
#   'does',
#   'barney',
#   'rubble',
#   'go',
#   'to',
#   'work',
#   'after',
#   'he',
#   'drops',
#   'fred',
#   'off',
#   'in',
#   'the',
#   '`',
#   '`',
#   'flint',
#   '##stones',
#   "'",
#   "'",
#   'cartoon',
#   'series',
#   '?'],
#  ['what', 'are', 'the', 'world', "'", 's', 'four', 'oceans', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'only',
#   'work',
#   'by',
#   'michelangelo',
#   'that',
#   'bears',
#   'his',
#   'signature',
#   '?'],
#  ['what', 'is', 'the', 'largest', 'snake', 'in', 'the', 'world', '?'],
#  ['in',
#   'what',
#   'medium',
#   'is',
#   'stuart',
#   'ham',
#   '##ble',
#   '##n',
#   'considered',
#   'to',
#   'be',
#   'the',
#   'first',
#   'singing',
#   'cowboy',
#   '?'],
#  ['where',
#   'on',
#   'the',
#   'internet',
#   'can',
#   'i',
#   'find',
#   'a',
#   'song',
#   'lyrics',
#   'database',
#   'similar',
#   'to',
#   'the',
#   'international',
#   'lyrics',
#   'server',
#   '?'],
#  ['how',
#   'much',
#   'money',
#   'does',
#   'a',
#   'back',
#   'injury',
#   'lawsuit',
#   'get',
#   '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'common',
#   'name',
#   'for',
#   'ace',
#   '##ty',
#   '##ls',
#   '##alic',
#   '##yl',
#   '##ic',
#   'acid',
#   '?'],
#  ['what',
#   'does',
#   'the',
#   'georgetown',
#   '`',
#   '`',
#   'ho',
#   '##ya',
#   "'",
#   "'",
#   'mean',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'a',
#   'list',
#   'of',
#   '`',
#   '`',
#   'classic',
#   "'",
#   "'",
#   'books',
#   '5th',
#   'and',
#   '6th',
#   'graders',
#   'should',
#   'read',
#   '?'],
#  ['which',
#   'two',
#   'products',
#   'use',
#   'a',
#   'tiger',
#   'as',
#   'their',
#   'symbol',
#   '?'],
#  ['how',
#   'is',
#   'the',
#   'election',
#   'of',
#   'a',
#   'new',
#   'pope',
#   'announced',
#   'to',
#   'the',
#   'world',
#   '?'],
#  ['how',
#   'long',
#   'does',
#   'it',
#   'take',
#   'for',
#   'your',
#   'blood',
#   'to',
#   'make',
#   'one',
#   'complete',
#   'trip',
#   'through',
#   'the',
#   'body',
#   '?'],
#  ['how', 'do', 'chickens', 'have', 'baby', 'chicks', '?'],
#  ['what',
#   'is',
#   'the',
#   'historical',
#   'relationship',
#   'of',
#   'catholic',
#   'church',
#   'and',
#   'bingo',
#   '?'],
#  ['how', 'was', 'the', 'element', 'calcium', 'named', '?'],
#  ['what',
#   'cr',
#   '##oon',
#   '##er',
#   'joined',
#   'the',
#   'andrews',
#   'sisters',
#   'for',
#   'pistol',
#   'pack',
#   '##in',
#   'mama',
#   '?'],
#  ['what',
#   'piano',
#   'company',
#   'claims',
#   'its',
#   'product',
#   'is',
#   'the',
#   '`',
#   '`',
#   'instrument',
#   'of',
#   'the',
#   'immortals',
#   "'",
#   "'",
#   '?'],
#  ['when', 'did', 'the', 'bounty', 'mutiny', 'take', 'place', '?'],
#  ['what', 'novel', 'inspired', 'the', 'movie', 'blade', '##runner', '?'],
#  ['what', 'is', 'a', 'trans', '##isto', '##r', '?'],
#  ['what', 'is', 'a', 'film', 'starring', 'jude', 'law', '?'],
#  ['what',
#   'hollywood',
#   'dog',
#   'died',
#   'in',
#   'the',
#   'arms',
#   'of',
#   'jean',
#   'harlow',
#   'in',
#   '1932',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'common',
#   'elements',
#   'in',
#   'the',
#   'earth',
#   "'",
#   's',
#   'crust',
#   '?'],
#  ['how',
#   'much',
#   'would',
#   'it',
#   'cost',
#   'to',
#   'purchase',
#   'a',
#   '2',
#   '-',
#   'foot',
#   '-',
#   'square',
#   'party',
#   'tent',
#   ',',
#   'with',
#   'sides',
#   ',',
#   '?'],
#  ['what',
#   'actress',
#   'has',
#   'received',
#   'the',
#   'most',
#   'oscar',
#   'nominations',
#   '?'],
#  ['what', 'are', 'equity', 'securities', '?'],
#  ['what', 'is', 'gym', '##no', '##phobia', '?'],
#  ['how', 'many', 'years', 'do', 'fossils', 'take', 'to', 'form', '?'],
#  ['where', 'is', 'the', 'or', '##ino', '##co', '?'],
#  ['what',
#   'was',
#   'the',
#   'name',
#   'of',
#   'the',
#   '`',
#   '`',
#   'little',
#   'ras',
#   '##cal',
#   '##s',
#   "'",
#   "'",
#   'dog',
#   '?'],
#  ['what',
#   'city',
#   'boasts',
#   'penn',
#   "'",
#   's',
#   'landing',
#   ',',
#   'on',
#   'the',
#   'banks',
#   'of',
#   'the',
#   'delaware',
#   'river',
#   '?'],
#  ['what',
#   'broadway',
#   'musical',
#   'was',
#   'inspired',
#   'by',
#   'ce',
#   '##rva',
#   '##ntes',
#   "'",
#   's',
#   'don',
#   'qui',
#   '##x',
#   '##ote',
#   '?'],
#  ['what', 'is', 'the', 'origin', 'of', 'the', 'word', ',', 'jj', '.'],
#  ['how',
#   'many',
#   'hostages',
#   'were',
#   'killed',
#   'in',
#   'the',
#   'en',
#   '##te',
#   '##bbe',
#   'raid',
#   '?'],
#  ['how', 'you', 'can', 'raise', 'your', 'iq', '?'],
#  ['what',
#   'does',
#   'in',
#   '##ri',
#   'stand',
#   'for',
#   'when',
#   'used',
#   'on',
#   'jesus',
#   "'",
#   'cross',
#   '?'],
#  ['who', 'produces', 'sp', '##uman', '##te', '?'],
#  ['who', 'earn', '##s', 'their', 'money', 'the', 'hard', 'way', '?'],
#  ['who', 'founded', 'the', 'people', "'", 's', 'temple', 'commune', '?'],
#  ['what',
#   'athlete',
#   'makes',
#   'the',
#   'most',
#   'money',
#   'from',
#   'sports',
#   'merchandise',
#   'sales',
#   '?'],
#  ['how',
#   'many',
#   'bends',
#   'are',
#   'there',
#   'in',
#   'a',
#   'standard',
#   'paper',
#   'clip',
#   '?'],
#  ['who', 'discovered', 'electricity', '?'],
#  ['what',
#   'part',
#   'of',
#   'your',
#   'body',
#   'contains',
#   'the',
#   'corpus',
#   'call',
#   '##os',
#   '##um',
#   '?'],
#  ['who', 'was', 'the', 'first', 'american', 'in', 'space', '?'],
#  ['what',
#   'two',
#   'south',
#   'american',
#   'countries',
#   'do',
#   'n',
#   "'",
#   't',
#   'border',
#   'brazil',
#   '?'],
#  ['what',
#   'album',
#   'put',
#   'the',
#   'beatles',
#   'on',
#   'the',
#   'cover',
#   'of',
#   'time',
#   'in',
#   '1967',
#   '?'],
#  ['what',
#   'poem',
#   'contains',
#   'the',
#   'line',
#   ',',
#   '`',
#   '`',
#   'grow',
#   'old',
#   'with',
#   'me',
#   'the',
#   'best',
#   'is',
#   'yet',
#   'to',
#   'be',
#   "'",
#   "'",
#   '.'],
#  ['what', 'is', 'a', 'dental', 'root', 'canal', '?'],
#  ['what',
#   'war',
#   'did',
#   'the',
#   'wanna',
#   '-',
#   'go',
#   '-',
#   'home',
#   'riots',
#   'occur',
#   'after',
#   '?'],
#  ['what', 'is', 'the', 'busiest', 'air', 'travel', 'season', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'colored',
#   'part',
#   'of',
#   'the',
#   'eye',
#   'called',
#   '?'],
#  ['what', 'are', 'hook', 'worms', '?'],
#  ['where', 'is', 'the', 'rose', 'bowl', 'played', '?'],
#  ['which',
#   'japanese',
#   'car',
#   'maker',
#   'had',
#   'its',
#   'biggest',
#   'percentage',
#   'of',
#   'sale',
#   'in',
#   'the',
#   'domestic',
#   'market',
#   '?'],
#  ['who', 'is', 'the', 'mayor', 'of', 'mar', '##bella', '?'],
#  ['what',
#   'sun',
#   '-',
#   'blasted',
#   ',',
#   '14',
#   '-',
#   'mile',
#   'wide',
#   'valley',
#   'is',
#   'just',
#   'north',
#   'of',
#   'the',
#   'mo',
#   '##ja',
#   '##ve',
#   'desert',
#   '?'],
#  ['in', 'what', 'year', 'did', 'thatcher', 'become', 'prime', 'minister', '?'],
#  ['how',
#   'many',
#   'months',
#   'does',
#   'it',
#   'take',
#   'the',
#   'moon',
#   'to',
#   'rev',
#   '##ol',
#   '##ve',
#   'around',
#   'the',
#   'earth',
#   '?'],
#  ['where', 'are', 'the', '49', 'steps', '?'],
#  ['in',
#   'what',
#   'year',
#   'was',
#   'de',
#   'gaulle',
#   'elected',
#   'president',
#   'of',
#   'france',
#   '?'],
#  ['who',
#   'sings',
#   'the',
#   'themes',
#   'for',
#   '`',
#   '`',
#   'dawson',
#   "'",
#   's',
#   'creek',
#   "'",
#   "'",
#   'and',
#   '`',
#   '`',
#   'felicity',
#   "'",
#   "'",
#   '?'],
#  ['who', 'directed', '`', '`', 'jaws', "'", "'", '?'],
#  ['on',
#   'what',
#   't',
#   '.',
#   'v',
#   '.',
#   'show',
#   'could',
#   'tom',
#   'terrific',
#   'be',
#   'found',
#   '?'],
#  ['what',
#   'indian',
#   'tribe',
#   'is',
#   'f',
#   'troop',
#   'perpetual',
#   '##ly',
#   'doing',
#   'battle',
#   'with',
#   '?'],
#  ['where', 'did', 'indian', 'pudding', 'come', 'from', '?'],
#  ['why',
#   'do',
#   'some',
#   'clothing',
#   'labels',
#   'say',
#   '`',
#   '`',
#   'use',
#   'a',
#   'non',
#   '##ch',
#   '##lor',
#   '##ine',
#   'b',
#   '##lea',
#   '##ch',
#   "'",
#   "'",
#   '?'],
#  ['how',
#   'many',
#   'colonies',
#   'were',
#   'involved',
#   'in',
#   'the',
#   'american',
#   'revolution',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'name',
#   'of',
#   'the',
#   'city',
#   'that',
#   'ma',
#   '##uri',
#   '##zio',
#   'pe',
#   '##lle',
#   '##grin',
#   'lives',
#   'in',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'pictorial',
#   'directions',
#   'on',
#   'how',
#   'to',
#   'build',
#   'a',
#   'very',
#   'simple',
#   'tree',
#   '##house',
#   '?'],
#  ['what',
#   'game',
#   "'",
#   's',
#   'board',
#   'shows',
#   'the',
#   'territories',
#   'of',
#   'ir',
#   '##ku',
#   '##tsk',
#   ',',
#   'ya',
#   '##ku',
#   '##tsk',
#   'and',
#   'kam',
#   '##cha',
#   '##t',
#   '##ka',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'name',
#   'of',
#   'the',
#   'managing',
#   'director',
#   'of',
#   'apr',
#   '##ico',
#   '##t',
#   'computer',
#   '?'],
#  ['what', 'is', 'the', 'occupation', 'of', 'nicholas', 'cage', '?'],
#  ['why', 'do', 'horseshoe', '##s', 'bring', 'luck', '?'],
#  ['what', 'is', 'the', '401', ',', 'k', ',', 'plan', '?'],
#  ['what', 'causes', 'pneumonia', '?'],
#  ['what',
#   'are',
#   'the',
#   'three',
#   'winter',
#   'months',
#   'in',
#   'the',
#   'southern',
#   'hemisphere',
#   '?'],
#  ['what', 'does', 'grin', '##go', 'mean', '?'],
#  ['what',
#   'country',
#   'contains',
#   'africa',
#   "'",
#   's',
#   'northernmost',
#   'point',
#   '?'],
#  ['what',
#   'therapy',
#   'attempts',
#   'to',
#   'eli',
#   '##cit',
#   'the',
#   '`',
#   '`',
#   'primal',
#   'scream',
#   "'",
#   "'",
#   '?'],
#  ['where', 'is', 'the', 'kala', '##hari', 'desert', '?'],
#  ['which',
#   'ventura',
#   'county',
#   'police',
#   'department',
#   'seized',
#   'the',
#   'largest',
#   'cocaine',
#   'shipment',
#   'in',
#   'it',
#   "'",
#   's',
#   'history',
#   '?'],
#  ['what', 'city', 'is', 'sometimes', 'called', 'gotham', '?'],
#  ['what',
#   'dan',
#   '##gles',
#   'over',
#   'the',
#   'tongue',
#   'from',
#   'the',
#   'pal',
#   '##ate',
#   '?'],
#  ['who', 'created', 'dennis', 'the', 'menace', '?'],
#  ['what',
#   'dummy',
#   'received',
#   'an',
#   'honorary',
#   'degree',
#   'from',
#   'northwestern',
#   'university',
#   '?'],
#  ['when',
#   'was',
#   'the',
#   'first',
#   'wall',
#   'street',
#   'journal',
#   'published',
#   '?'],
#  ['what', 'countries', 'have', 'the', 'largest', 'areas', 'of', 'forest', '?'],
#  ['how', 'do', 'i', 'start', 'a', 'web', 'based', 'business', '?'],
#  ['name', 'alvin', "'", 's', 'brothers'],
#  ['what',
#   'is',
#   'eagle',
#   "'",
#   's',
#   'syndrome',
#   'st',
#   '##yl',
#   '##oid',
#   'process',
#   '?'],
#  ['how', 'did', 'jayne', 'mansfield', 'die', '?'],
#  ['when',
#   'did',
#   'the',
#   'royal',
#   'wedding',
#   'of',
#   'prince',
#   'andrew',
#   'and',
#   'fe',
#   '##rg',
#   '##ie',
#   'take',
#   'place',
#   '?'],
#  ['what',
#   'actor',
#   'said',
#   'in',
#   'a',
#   'day',
#   'at',
#   'the',
#   'races',
#   ':',
#   '`',
#   '`',
#   'either',
#   'he',
#   "'",
#   's',
#   'dead',
#   'or',
#   'my',
#   'watch',
#   'has',
#   'stopped',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'explorer',
#   'was',
#   'nicknamed',
#   'ib',
#   '##eria',
#   "'",
#   's',
#   'pilot',
#   '?'],
#  ['cnn', 'began', 'broadcasting', 'in', 'what', 'year', '?'],
#  ['what',
#   'is',
#   'a',
#   'ball',
#   'that',
#   'hits',
#   'the',
#   'foul',
#   'pole',
#   'called',
#   '?'],
#  ['what',
#   'makes',
#   'hamburger',
#   '##s',
#   'taste',
#   'like',
#   'steak',
#   '##burg',
#   '##ers',
#   '?'],
#  ['which', 'company', 'created', 'the', 'internet', 'browser', 'mosaic', '?'],
#  ['what',
#   'are',
#   'the',
#   'rites',
#   'accompanying',
#   'the',
#   'ci',
#   '##rc',
#   '##um',
#   '##cision',
#   'of',
#   'a',
#   'newly',
#   'born',
#   '-',
#   'child',
#   'in',
#   'judaism',
#   'called',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'education',
#   'system',
#   'in',
#   'the',
#   '1960',
#   "'",
#   's',
#   '?'],
#  ['what',
#   'south',
#   'american',
#   'city',
#   'has',
#   'the',
#   'world',
#   "'",
#   's',
#   'highest',
#   'commercial',
#   'landing',
#   'field',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'find',
#   'out',
#   'which',
#   'cities',
#   'have',
#   'cable',
#   '-',
#   'mode',
#   '##m',
#   'access',
#   '?'],
#  ['what', 'is', 'betsy', 'ross', 'famous', 'for', '?'],
#  ['how', 'many', 'species', 'of', 'sharks', 'are', 'there', '?'],
#  ['what', 'is', '`', '`', 's', '##no', '##ogan', '##s', "'", "'", '?'],
#  ['how', 'many', 'people', 'are', 'there', 'in', 'the', 'world', '?'],
#  ['what',
#   'shrubs',
#   'can',
#   'be',
#   'planted',
#   'that',
#   'will',
#   'be',
#   'safe',
#   'from',
#   'deer',
#   '?'],
#  ['what',
#   'organization',
#   "'",
#   's',
#   'offices',
#   'were',
#   'broken',
#   'into',
#   'at',
#   'water',
#   '##gate',
#   'in',
#   '1972',
#   '?'],
#  ['what', 'is', 'the', 'design', 'of', 'the', 'ship', 'titanic', '?'],
#  ['what', 'does', 's', '.', 'o', '.', 's', '.', 'stand', 'for', '?'],
#  ['name',
#   'a',
#   'technique',
#   'widely',
#   'used',
#   'to',
#   'detect',
#   'birth',
#   'defects',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'daily',
#   'requirement',
#   'of',
#   'f',
#   '##olic',
#   'acid',
#   'for',
#   'an',
#   'expect',
#   '##ant',
#   'mother',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   '`',
#   '`',
#   '7',
#   '-',
#   'minute',
#   'cigarette',
#   "'",
#   "'",
#   '?'],
#  ['what', 'four', 'forms', 'does', 'gold', 'occur', 'in', '?'],
#  ['what',
#   'is',
#   'the',
#   'acre',
#   '##age',
#   'of',
#   'the',
#   'cha',
#   '##ppel',
#   '##let',
#   'vineyard',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'correctly',
#   'say',
#   'the',
#   'word',
#   '`',
#   'qi',
#   '##gong',
#   "'",
#   '?'],
#  ['when', 'did', 'beethoven', 'die', '?'],
#  ['how', 'much', 'does', 'a', 'new', 'railroad', 'coal', 'car', 'cost', '?'],
#  ['what',
#   'two',
#   'european',
#   'countries',
#   'entered',
#   'the',
#   'war',
#   'of',
#   'american',
#   'independence',
#   'against',
#   'the',
#   'british',
#   '?'],
#  ['what', 'is', 'the', 'filmmakers', 'col', '##lab', '##rative', '?'],
#  ['what',
#   'russian',
#   'composer',
#   "'",
#   's',
#   'prelude',
#   'in',
#   'c',
#   'sharp',
#   'minor',
#   'brought',
#   'him',
#   'fame',
#   'and',
#   'fortune',
#   '?'],
#  ['what', 'caused', 'harry', 'ho', '##udi', '##ni', "'", 's', 'death', '?'],
#  ['who',
#   'was',
#   'the',
#   'mother',
#   'of',
#   'the',
#   'man',
#   'who',
#   'would',
#   'not',
#   'be',
#   'king',
#   ',',
#   'the',
#   'duke',
#   'of',
#   'windsor',
#   '?'],
#  ['how',
#   'many',
#   'revolutions',
#   'does',
#   'a',
#   'standard',
#   'lp',
#   'make',
#   'in',
#   'three',
#   'minutes',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'name',
#   'of',
#   'the',
#   'tallest',
#   'mountain',
#   'in',
#   'the',
#   'world',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'a',
#   'review',
#   'of',
#   'nightmare',
#   'on',
#   'elm',
#   'street',
#   'in',
#   'a',
#   'film',
#   'journal',
#   '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'slow',
#   '##est',
#   'olympic',
#   'swimming',
#   'stroke',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'name',
#   'of',
#   'the',
#   'first',
#   'russian',
#   'astronaut',
#   'to',
#   'do',
#   'a',
#   'space',
#   '##walk',
#   '?'],
#  ['what',
#   'disease',
#   'is',
#   'transmitted',
#   'by',
#   'the',
#   'an',
#   '##op',
#   '##hel',
#   '##es',
#   'mosquito',
#   '?'],
#  ['what',
#   'rum',
#   'is',
#   'so',
#   '`',
#   '`',
#   'mix',
#   '##able',
#   "'",
#   "'",
#   'it',
#   'is',
#   'a',
#   'one',
#   '-',
#   'brand',
#   'bar',
#   '?'],
#  ['how',
#   'many',
#   'south',
#   'american',
#   'countries',
#   'have',
#   'the',
#   'letter',
#   'z',
#   'in',
#   'their',
#   'names',
#   '?'],
#  ['what', 'is', 'the', 'contents', 'of', 'proposition', '98', '?'],
#  ['where', 'was', 'george', 'washington', 'born', '?'],
#  ['how',
#   'many',
#   'people',
#   'on',
#   'the',
#   'ground',
#   'were',
#   'killed',
#   'from',
#   'the',
#   'bombing',
#   'of',
#   'pan',
#   'am',
#   'flight',
#   '103',
#   'over',
#   'locker',
#   '##bie',
#   ',',
#   'scotland',
#   ',',
#   'december',
#   '21',
#   ',',
#   'cd',
#   '.'],
#  ['who', 'wrote', 'n', '##n', 'dt', 'n', '##np', 'n', '##np', "'", "'", '?'],
#  ['what', 'is', 'para', '##ce', '##tam', '##ol', '?'],
#  ['what',
#   'are',
#   'the',
#   'powers',
#   'and',
#   'weaknesses',
#   'of',
#   'green',
#   'lantern',
#   "'",
#   's',
#   'ring',
#   '?'],
#  ['which',
#   'mosquito',
#   "'",
#   's',
#   'bite',
#   'draws',
#   'blood',
#   ',',
#   'dt',
#   'n',
#   '##n',
#   'cc',
#   'dt',
#   'n',
#   '##n',
#   '.'],
#  ['when',
#   'was',
#   'the',
#   'first',
#   'steel',
#   'mill',
#   'in',
#   'the',
#   'united',
#   'states',
#   'built',
#   '?'],
#  ['what',
#   'dim',
#   '##in',
#   '##utive',
#   'american',
#   'female',
#   'gymnast',
#   'stole',
#   'the',
#   'show',
#   'at',
#   'the',
#   '1984',
#   'olympics',
#   '?'],
#  ['what', 'is', 'the', 'origin', 'of', 'the', 'name', 'katie', '?'],
#  ['what',
#   'schools',
#   'in',
#   'the',
#   'washington',
#   ',',
#   'dc',
#   'n',
#   '##n',
#   'n',
#   '##n',
#   'v',
#   '##b',
#   '##p',
#   'n',
#   '##n',
#   'n',
#   '##n',
#   'n',
#   '##n',
#   'n',
#   '##n',
#   '.'],
#  ['when', 'did', 'the', 'berlin', 'wall', 'go', 'up', '?'],
#  ['who', 'is', 'terre', '##nce', 'mali', '##ck', '?'],
#  ['what',
#   'instrument',
#   'is',
#   'ray',
#   'charles',
#   'best',
#   'known',
#   'for',
#   'playing',
#   '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'meaning',
#   'of',
#   'the',
#   'latin',
#   'battle',
#   'cry',
#   ':',
#   'ad',
#   'arm',
#   '##a',
#   ',',
#   'ad',
#   'arm',
#   '##a',
#   '.'],
#  ['what', 'is', 'the', 'mascot', 'for', 'notre', 'dame', 'university', '?'],
#  ['what',
#   'las',
#   'vegas',
#   'hotel',
#   'burned',
#   'in',
#   'november',
#   ',',
#   '1980',
#   ',',
#   'with',
#   'the',
#   'loss',
#   'of',
#   '84',
#   'lives',
#   '?'],
#  ['when',
#   'did',
#   'mount',
#   'st',
#   '.',
#   'helen',
#   'last',
#   'have',
#   'a',
#   'significant',
#   'eruption',
#   '?'],
#  ['cnn', 'is', 'the', 'abbreviation', 'for', 'what', '?'],
#  ['when', 'did', 'world', 'war', 'i', 'start', '?'],
#  ['how', 'many', 'feet', 'are', 'there', 'in', 'a', 'fat', '##hom', '?'],
#  ['what', 'is', 'a', 'canada', 'two', '-', 'penny', 'black', '?'],
#  ['what', 'european', 'city', 'do', 'nico', '##is', 'live', 'in', '?'],
#  ['how',
#   'can',
#   'i',
#   'find',
#   'out',
#   'what',
#   'year',
#   'a',
#   'bean',
#   '##ie',
#   'baby',
#   'was',
#   'introduced',
#   '?'],
#  ['what', 'is', 'the', 'classic', 'definition', 'of', 'tragic', 'hero', '?'],
#  ['to',
#   'what',
#   'does',
#   'microsoft',
#   "'",
#   's',
#   'windows',
#   '3',
#   'owe',
#   'its',
#   'success',
#   '?'],
#  ['who', 'was', 'president', 'of', 'afghanistan', 'in', '1994', '?'],
#  ['what',
#   'are',
#   'other',
#   'ways',
#   'of',
#   'getting',
#   'stretch',
#   'marks',
#   'besides',
#   'pregnancy',
#   ',',
#   'weight',
#   'loss',
#   ',',
#   'and',
#   'weight',
#   'lifting',
#   '?'],
#  ['what', 'did', 'bro', '##nto', '##saurus', '##es', 'eat', '?'],
#  ['what',
#   'color',
#   'bottles',
#   'do',
#   'good',
#   'rhine',
#   'wines',
#   'come',
#   'in',
#   '?'],
#  ['who',
#   'was',
#   'the',
#   'lead',
#   'actress',
#   'in',
#   'the',
#   'movie',
#   '`',
#   'sleep',
#   '##less',
#   'in',
#   'seattle',
#   "'",
#   '?'],
#  ['who',
#   'was',
#   'the',
#   '16th',
#   'president',
#   'of',
#   'the',
#   'united',
#   'states',
#   '?'],
#  ['who',
#   'are',
#   'the',
#   'two',
#   'sons',
#   'of',
#   'oz',
#   '##zie',
#   'and',
#   'harriet',
#   'nelson',
#   '?'],
#  ['what', 'is', 'mo', '##ly', '##b', '##den', '##um', '?'],
#  ['when', 'is', 'boxing', 'day', '?'],
#  ['what',
#   'is',
#   'the',
#   'lowest',
#   'level',
#   'of',
#   'the',
#   'american',
#   'judiciary',
#   '?'],
#  ['when', 'was', 'the', 'battle', 'of', 'the', 'somme', 'fought', '?'],
#  ['how', 'many', 'people', 'did', 'randy', 'craft', 'kill', '?'],
#  ['what', "'", 's', 'the', 'official', 'animal', 'of', 'canada', '?'],
#  ['when', 'did', 'spielberg', 'direct', '`', '`', 'jaws', "'", "'", '?'],
#  ['what', 'is', 'the', 'size', 'of', 'the', 'largest', 'ak', '##ita', '?'],
#  ['what', 'animal', 'has', 'the', 'biggest', 'eyes', '?'],
#  ['what', 'is', 'california', "'", 's', 'capital', '?'],
#  ['who',
#   'was',
#   'the',
#   'author',
#   'of',
#   'the',
#   'book',
#   'about',
#   'computer',
#   'hacker',
#   '##s',
#   'called',
#   '`',
#   '`',
#   'the',
#   'cuckoo',
#   "'",
#   's',
#   'egg',
#   ':',
#   'tracking',
#   'a',
#   'spy',
#   'through',
#   'the',
#   'maze',
#   'of',
#   'computer',
#   'espionage',
#   "'",
#   "'",
#   '?'],
#  ['who',
#   'was',
#   'the',
#   'founding',
#   'member',
#   'of',
#   'the',
#   'pink',
#   'floyd',
#   'band',
#   '?'],
#  ['what',
#   'european',
#   'country',
#   'is',
#   'home',
#   'to',
#   'the',
#   'beer',
#   '-',
#   'producing',
#   'city',
#   'of',
#   'bud',
#   '##wei',
#   '##s',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'find',
#   'the',
#   'balance',
#   'of',
#   'my',
#   'social',
#   'security',
#   'account',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'history',
#   'of',
#   'valentine',
#   "'",
#   's',
#   'day',
#   'cards',
#   '?'],
#  ['where', 'was', 'christopher', 'columbus', 'born', '?'],
#  ['what', 'do', 'italians', 'call', 'florence', '?'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'to',
#   'the',
#   'top',
#   'of',
#   'the',
#   'e',
#   '##iff',
#   '##el',
#   'tower',
#   '?'],
#  ['what', 'does', '`', 'psi', "'", 'stand', 'for', '?'],
#  ['what', 'sea', 'did', 'the', 'romans', 'call', 'mare', 'nos', '##trum', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'term',
#   'for',
#   'a',
#   'bet',
#   'before',
#   'cards',
#   'are',
#   'dealt',
#   '?'],
#  ['which',
#   'came',
#   'first',
#   ',',
#   'according',
#   'to',
#   'genesis',
#   '1',
#   ':',
#   '2',
#   ':',
#   '22',
#   '-',
#   'the',
#   'chicken',
#   'or',
#   'the',
#   'egg',
#   '?'],
#  ['what', 'city', 'did', 'the', 'flint', '##stones', 'live', 'in', '?'],
#  ['what', 'is', 'latin', 'for', 'inc', '##omp', '##ete', '##nt', '?'],
#  ['what', 'chemicals', 'are', 'used', 'in', 'lethal', 'injection', '?'],
#  ['what',
#   'toy',
#   'company',
#   'is',
#   'the',
#   'world',
#   "'",
#   's',
#   'no',
#   '.',
#   '1',
#   'maker',
#   'of',
#   'female',
#   'apparel',
#   '?'],
#  ['what',
#   'board',
#   'game',
#   'does',
#   'a',
#   '`',
#   '`',
#   'wood',
#   '-',
#   'push',
#   '##er',
#   "'",
#   "'",
#   'play',
#   'poorly',
#   '?'],
#  ['which',
#   'doo',
#   '##nes',
#   '##bury',
#   'character',
#   'was',
#   'likely',
#   'to',
#   'turn',
#   'into',
#   'a',
#   'werewolf',
#   '?'],
#  ['what', 'is', 'the', 'abbreviation', 'for', 'micro', '?'],
#  ['what', 'are', 'the', '7', 'articles', 'of', 'the', 'constitution', '?'],
#  ['who', 'has', 'won', 'the', 'most', 'super', 'bowls', '?'],
#  ['what', 'does', 'nas', '##da', '##q', 'stand', 'for', '?'],
#  ['what', 'is', 'bp', '##h', '?'],
#  ['what',
#   'is',
#   'the',
#   'fastest',
#   'commercial',
#   'automobile',
#   'that',
#   'can',
#   'be',
#   'bought',
#   'in',
#   'the',
#   'us',
#   '?'],
#  ['what',
#   'stadium',
#   'do',
#   'the',
#   'miami',
#   'dolphins',
#   'play',
#   'their',
#   'home',
#   'games',
#   'in',
#   '?'],
#  ['who',
#   'has',
#   'the',
#   'only',
#   'speaking',
#   'role',
#   'in',
#   '`',
#   '`',
#   'silent',
#   'movie',
#   "'",
#   "'",
#   '?'],
#  ['why', 'is', 'po', '##op', 'sometimes', 'different', 'colors', '?'],
#  ['what', 'was', 'einstein', "'", 's', 'iq', '?'],
#  ['what', 'day', 'was', 'pearl', 'harbor', 'attacked', 'in', '1942', '?'],
#  ['what',
#   'girl',
#   "'",
#   's',
#   'name',
#   'is',
#   '`',
#   '`',
#   'teddy',
#   "'",
#   "'",
#   'an',
#   'affection',
#   '##ate',
#   'form',
#   'of',
#   '?'],
#  ['what', 'state', 'is', 'john', 'f', '.', 'kennedy', 'buried', 'in', '?'],
#  ['what', 'is', 'the', 'best', 'way', 'to', 'remove', 'wall', '##paper', '?'],
#  ['what',
#   'u',
#   '.',
#   's',
#   '.',
#   'state',
#   'has',
#   'an',
#   'element',
#   'named',
#   'for',
#   'it',
#   '?'],
#  ['what',
#   'company',
#   'tab',
#   '##ulates',
#   'the',
#   'ballots',
#   'in',
#   'voting',
#   'for',
#   'the',
#   'academy',
#   'awards',
#   '?'],
#  ['how', 'did', 'the', 'tradition', 'of', 'best', 'man', 'start', '?'],
#  ['how', 'many', 'years', 'ago', 'did', 'the', 'ship', 'titanic', 'sink', '?'],
#  ['what', 'is', 'the', 'deepest', 'area', 'of', 'the', 'arctic', 'ocean', '?'],
#  ['what', 'are', 'halloween', "'", 's', 'colors', '?'],
#  ['how', 'is', 'silk', 'screening', 'done', '?'],
#  ['what',
#   'is',
#   'the',
#   'latitude',
#   'and',
#   'longitude',
#   'of',
#   'el',
#   'paso',
#   ',',
#   'texas',
#   '?'],
#  ['who', 'made', 'a', 'boat', 'out', 'of', 'go', '##pher', 'wood', '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'a',
#   '`',
#   '`',
#   'fifth',
#   'element',
#   "'",
#   "'",
#   'screens',
#   '##aver',
#   '?'],
#  ['which',
#   'bloom',
#   'county',
#   'resident',
#   'wr',
#   '##eak',
#   '##s',
#   'havoc',
#   'with',
#   'a',
#   'computer',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'match',
#   'a',
#   'name',
#   'to',
#   'a',
#   'social',
#   'security',
#   'number',
#   '?'],
#  ['how', 'does', 'a', 'rainbow', 'form', '?'],
#  ['what',
#   'is',
#   'the',
#   'normal',
#   'resting',
#   'heart',
#   'rate',
#   'of',
#   'a',
#   'healthy',
#   'adult',
#   '?'],
#  ['what', 'is', 'the', 'population', 'of', 'ohio', '?'],
#  ['how',
#   'many',
#   'cal',
#   '##ories',
#   'are',
#   'there',
#   'in',
#   'a',
#   'big',
#   'mac',
#   '?'],
#  ['ha', '##z', '##mat', 'stands', 'for', 'what', '?'],
#  ['what',
#   'creature',
#   'scares',
#   'people',
#   'in',
#   'the',
#   'film',
#   '`',
#   '`',
#   'jaws',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'part',
#   'did',
#   'john',
#   'peter',
#   'zen',
#   '##ger',
#   'play',
#   'in',
#   'the',
#   'dev',
#   '##eo',
#   '##pment',
#   'of',
#   'the',
#   'newspaper',
#   'in',
#   'america',
#   '?'],
#  ['who', 'followed', 'caesar', '?'],
#  ['what', 'are', 'the', 'four', 'elements', '?'],
#  ['who',
#   'was',
#   'the',
#   'first',
#   'woman',
#   'golfer',
#   'to',
#   'earn',
#   'a',
#   'million',
#   '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'tallest',
#   'piece',
#   'on',
#   'a',
#   'chess',
#   '##board',
#   '?'],
#  ['what', 'is', 'answers', '.', 'com', "'", 's', 'address', '?'],
#  ['where',
#   'can',
#   'i',
#   'buy',
#   'movies',
#   'on',
#   'video',
#   '##ta',
#   '##pe',
#   'online',
#   '?'],
#  ['who',
#   'does',
#   'the',
#   'ad',
#   '##vert',
#   '##izing',
#   'for',
#   'fr',
#   '##ito',
#   '-',
#   'lay',
#   '?'],
#  ['who',
#   'is',
#   'the',
#   'leading',
#   'competitor',
#   'of',
#   'trans',
#   'union',
#   'company',
#   '?'],
#  ['what',
#   'product',
#   'did',
#   'robert',
#   'conrad',
#   'dare',
#   'people',
#   'to',
#   'knock',
#   'off',
#   'his',
#   'shoulder',
#   '?'],
#  ['who', 'invented', 'the', 'radio', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'american',
#   'dollar',
#   'equivalent',
#   'for',
#   '8',
#   'pounds',
#   'in',
#   'the',
#   'u',
#   '.',
#   'k',
#   '.',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'different',
#   'approaches',
#   'of',
#   'systems',
#   'analysis',
#   '?'],
#  ['how', 'do', 'doctors', 'dia', '##gno', '##se', 'bone', 'cancer', '?'],
#  ['who',
#   'is',
#   'the',
#   'man',
#   'behind',
#   'the',
#   'pig',
#   '-',
#   'the',
#   'man',
#   'who',
#   'pulls',
#   'the',
#   'strings',
#   'and',
#   'speaks',
#   'for',
#   'miss',
#   'pig',
#   '##gy',
#   '?'],
#  ['what', 'is', 'the', 'speed', 'of', 'the', 'mississippi', 'river', '?'],
#  ['what', 'are', 'the', 'developmental', 'stages', 'of', 'a', 'swimmer', '?'],
#  ['what', 'actor', 'first', 'portrayed', 'james', 'bond', '?'],
#  ['what', 'ocean', 'is', 'the', 'largest', 'in', 'the', 'world', '?'],
#  ['who',
#   'was',
#   'the',
#   'first',
#   'american',
#   'poet',
#   'to',
#   'win',
#   'the',
#   'nobel',
#   'prize',
#   'for',
#   'literature',
#   ',',
#   'in',
#   '1948',
#   '?'],
#  ['what',
#   'year',
#   'did',
#   'jack',
#   'nick',
#   '##laus',
#   'join',
#   'the',
#   'professional',
#   'golfer',
#   '##s',
#   'association',
#   'tour',
#   '?'],
#  ['how', 'many', 'son', '##nets', 'did', 'shakespeare', 'write', '?'],
#  ['what',
#   'causes',
#   'the',
#   'red',
#   '##ness',
#   'in',
#   'your',
#   'cheeks',
#   'when',
#   'you',
#   'blush',
#   '?'],
#  ['who', 'won', 'the', 'nobel', 'peace', 'prize', 'in', '1991', '?'],
#  ['who', 'are', 'the', 'challenger', '##s', 'of', 'the', 'unknown', '?'],
#  ['define', 'the', 'ph', '##eon', '##ix', 'club', '?'],
#  ['which',
#   'city',
#   'did',
#   'christian',
#   'crusaders',
#   'fight',
#   'to',
#   'recapture',
#   'from',
#   'the',
#   'muslims',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   '`',
#   '`',
#   'ru',
#   '##pee',
#   'de',
#   '##pre',
#   '##cia',
#   '##tes',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'gaming',
#   'devices',
#   'were',
#   'dubbed',
#   '`',
#   '`',
#   'mississippi',
#   'marble',
#   '##s',
#   "'",
#   "'",
#   'and',
#   '`',
#   '`',
#   'memphis',
#   'domino',
#   '##es',
#   "'",
#   "'",
#   '?'],
#  ['who',
#   'was',
#   'the',
#   'first',
#   'coach',
#   'of',
#   'the',
#   'cleveland',
#   'browns',
#   '?'],
#  ['how', 'successful', 'is', 'ar', '##ome', '##therapy', '?'],
#  ['what',
#   'jewish',
#   'holiday',
#   'saw',
#   'the',
#   'start',
#   'of',
#   'the',
#   '1973',
#   'mid',
#   '##ea',
#   '##st',
#   'war',
#   '?'],
#  ['how', 'does', 'a', 'cop', '##ier', 'work', '?'],
#  ['what', 'is', 'the', 'speed', 'of', 'the', 'mississippi', 'river', '?'],
#  ['who',
#   'said',
#   'of',
#   'super',
#   'bowl',
#   'iii',
#   'in',
#   '1969',
#   ':',
#   '`',
#   '`',
#   'we',
#   "'",
#   'll',
#   'win',
#   '-',
#   'i',
#   'guarantee',
#   'it',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'is',
#   'dudley',
#   'do',
#   '-',
#   'right',
#   "'",
#   's',
#   'horse',
#   "'",
#   's',
#   'name',
#   '?'],
#  ['who',
#   'declared',
#   ':',
#   '`',
#   '`',
#   'i',
#   'am',
#   'down',
#   'on',
#   'whore',
#   '##s',
#   'and',
#   'i',
#   'shan',
#   "'",
#   't',
#   'stop',
#   'ripping',
#   'them',
#   "'",
#   "'",
#   '?'],
#  ['where', 'does', 'chocolate', 'come', 'from', '?'],
#  ['what',
#   'tv',
#   'game',
#   'show',
#   'once',
#   'saw',
#   'a',
#   'contestant',
#   'admit',
#   'to',
#   'picking',
#   'his',
#   'toes',
#   'in',
#   'the',
#   'shower',
#   '?'],
#  ['what', 'soviet', 'leader', 'owned', 'a', 'rolls', '-', 'royce', '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'a',
#   'case',
#   'on',
#   'individuals',
#   'with',
#   'disabilities',
#   'education',
#   'act',
#   'of',
#   '1991',
#   '?'],
#  ['what',
#   'war',
#   'did',
#   'florence',
#   'nightingale',
#   'tend',
#   'the',
#   'troops',
#   'in',
#   '?'],
#  ['who',
#   'wrote',
#   'the',
#   'song',
#   ',',
#   '`',
#   '`',
#   'star',
#   '##dust',
#   "'",
#   "'",
#   '?'],
#  ['how', 'many', 'beatles', "'", 'records', 'went', '#', '1', '?'],
#  ['who',
#   'is',
#   'the',
#   'only',
#   'prime',
#   'minister',
#   'of',
#   'canada',
#   'to',
#   'serve',
#   '22',
#   'years',
#   'but',
#   'not',
#   'necessarily',
#   'consecutive',
#   '##ly',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'abbreviation',
#   'of',
#   'the',
#   'company',
#   'name',
#   '`',
#   'general',
#   'motors',
#   "'",
#   '?'],
#  ['what',
#   'mountains',
#   'lie',
#   'between',
#   'the',
#   'arkansas',
#   'and',
#   'missouri',
#   'rivers',
#   '?'],
#  ['who', 'received', 'the', 'will', 'rogers', 'award', 'in', '1989', '?'],
#  ['what', 'is', 'the', 'function', 'of', 'ram', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'closest',
#   'g',
#   '##2',
#   'spectrum',
#   'yellow',
#   'dwarf',
#   'to',
#   'earth',
#   '?'],
#  ['how',
#   'many',
#   'equal',
#   'angles',
#   'are',
#   'there',
#   'in',
#   'an',
#   'iso',
#   '##sc',
#   '##eles',
#   'triangle',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'fear',
#   'of',
#   'cock',
#   '##ro',
#   '##ache',
#   '##s',
#   'called',
#   '?'],
#  ['what',
#   'cbs',
#   'soap',
#   'opera',
#   'was',
#   'interrupted',
#   'by',
#   'the',
#   'bulletin',
#   'of',
#   'john',
#   'f',
#   '.',
#   'kennedy',
#   "'",
#   's',
#   'assassination',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'use',
#   'of',
#   'a',
#   '24',
#   '-',
#   'hour',
#   'clock',
#   'instead',
#   'of',
#   'a',
#   '12',
#   '-',
#   'hour',
#   'clock',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'name',
#   'of',
#   'the',
#   'lawyer',
#   'who',
#   'represented',
#   'randy',
#   'craft',
#   '?'],
#  ['what',
#   'united',
#   'states',
#   'president',
#   'had',
#   'dreamed',
#   'that',
#   'he',
#   'was',
#   'assassinated',
#   '?'],
#  ['what',
#   'film',
#   'did',
#   'lee',
#   'marvin',
#   'win',
#   'the',
#   '1965',
#   'best',
#   'actor',
#   'oscar',
#   'for',
#   '?'],
#  ['where', 'is', 'basque', 'country', 'located', '?'],
#  ['what',
#   'product',
#   'does',
#   '`',
#   '`',
#   'mrs',
#   '.',
#   'olsen',
#   "'",
#   "'",
#   'promote',
#   '?'],
#  ['what',
#   'time',
#   'of',
#   'day',
#   'did',
#   'emperor',
#   'hi',
#   '##ro',
#   '##hit',
#   '##o',
#   'die',
#   '?'],
#  ['what', 'is', 'dry', 'ice', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'most',
#   'powerful',
#   'card',
#   'in',
#   'eu',
#   '##ch',
#   '##re',
#   '?'],
#  ['what',
#   'does',
#   '`',
#   '`',
#   'intra',
#   '##ctable',
#   'plant',
#   '##ar',
#   'ke',
# ...
#  ['what',
#   'does',
#   'an',
#   'average',
#   'day',
#   '##care',
#   'provider',
#   'get',
#   'paid',
#   'in',
#   'new',
#   'england',
#   '?'],
#  ['what',
#   'author',
#   'landed',
#   'a',
#   '46',
#   '##8',
#   '-',
#   'pound',
#   'mar',
#   '##lin',
#   'without',
#   'harness',
#   'in',
#   'the',
#   'early',
#   '193',
#   "'",
#   's',
#   '?'],
#  ['how',
#   'many',
#   'americans',
#   'fought',
#   'for',
#   'the',
#   'british',
#   'in',
#   'the',
#   'american',
#   'revolution',
#   '?'],
#  ['what',
#   'kind',
#   'of',
#   'education',
#   'do',
#   'i',
#   'need',
#   'to',
#   'become',
#   'a',
#   'flight',
#   'attendant',
#   '?'],
#  ['what', 'are', 'the', 'two', 'languages', 'of', 'malta', '?'],
#  ['how', 'many', 'oceans', 'are', 'there', 'and', 'name', 'them', '?'],
#  ['what',
#   'happened',
#   'during',
#   'the',
#   'black',
#   '##hawk',
#   'indian',
#   'war',
#   'of',
#   '1832',
#   '?'],
#  ['how', 'many', 'pairs', 'of', 'legs', 'does', 'a', 'lobster', 'have', '?'],
#  ['what', 'does', 'the', 'latin', 'ant', '##e', 'mort', '##em', 'mean', '?'],
#  ['what', 'does', 'the', 'name', 'shawn', 'mean', '?'],
#  ['where', 'is', 'the', 'danube', '?'],
#  ['what',
#   'lawyer',
#   'won',
#   'the',
#   'largest',
#   'divorce',
#   'settlement',
#   ',',
#   '$',
#   '85',
#   'million',
#   ',',
#   'in',
#   'u',
#   '.',
#   's',
#   '.',
#   'history',
#   'for',
#   'she',
#   '##ika',
#   'den',
#   '##a',
#   'al',
#   '-',
#   'far',
#   '##ri',
#   '?'],
#  ['what', 'do', 'you', 'call', 'a', 'group', 'of', 'geese', '?'],
#  ['who',
#   'delivered',
#   'his',
#   'last',
#   'newscast',
#   'on',
#   'march',
#   '6',
#   ',',
#   '1981',
#   '?'],
#  ['how',
#   'many',
#   'times',
#   'has',
#   '`',
#   '`',
#   'louie',
#   ',',
#   'louie',
#   "'",
#   "'",
#   'been',
#   'recorded',
#   '?'],
#  ['how',
#   'is',
#   'answers',
#   '.',
#   'com',
#   'different',
#   'from',
#   'know',
#   '##post',
#   '.',
#   'com',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'longest',
#   'place',
#   'name',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   '?'],
#  ['what',
#   'percent',
#   'liked',
#   'thatcher',
#   'after',
#   'she',
#   'had',
#   'been',
#   'in',
#   'power',
#   'for',
#   'a',
#   'decade',
#   '?'],
#  ['where',
#   'does',
#   'buzz',
#   'al',
#   '##dr',
#   '##in',
#   'want',
#   'to',
#   'build',
#   'a',
#   'permanent',
#   ',',
#   'manned',
#   'space',
#   'station',
#   '?'],
#  ['what', 'was', 'mel', 'gibson', "'", 's', 'first', 'movie', '?'],
#  ['why',
#   'was',
#   'the',
#   'l',
#   '.',
#   'a',
#   '.',
#   'office',
#   'of',
#   'shea',
#   'and',
#   'gould',
#   'closed',
#   '?'],
#  ['how', 'do', 'i', 'start', 'a', 'bank', '?'],
#  ['how', 'do', 'ou', '##ija', 'boards', 'work', '?'],
#  ['what', 'horse', 'did', 'z', '##orro', 'ride', '?'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'a',
#   'broken',
#   'cork',
#   'out',
#   'of',
#   'a',
#   'bottle',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'correct',
#   'tab',
#   '##s',
#   'for',
#   'third',
#   'eye',
#   'blind',
#   'songs',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'determine',
#   'heating',
#   'requirements',
#   'for',
#   'your',
#   'home',
#   '?'],
#  ['what',
#   'former',
#   'major',
#   '-',
#   'league',
#   'left',
#   '-',
#   'handed',
#   'baseball',
#   'pitcher',
#   'was',
#   'known',
#   'as',
#   '`',
#   '`',
#   'space',
#   'man',
#   "'",
#   "'",
#   '?'],
#  ['which',
#   'hair',
#   'care',
#   'product',
#   'told',
#   'us',
#   '`',
#   '`',
#   'hate',
#   'that',
#   'gray',
#   ',',
#   'wash',
#   'it',
#   'away',
#   "'",
#   "'",
#   '?'],
#  ['why', 'did', 'the', 'chicken', 'cross', 'the', 'road', '?'],
#  ['what', 'was', 'michelangelo', "'", 's', 'last', 'name', '?'],
#  ['who', 'is', 'barbara', 'jordan', '?'],
#  ['who',
#   'was',
#   'the',
#   'democratic',
#   'nominee',
#   'in',
#   'the',
#   'american',
#   'presidential',
#   'election',
#   '?'],
#  ['what',
#   'was',
#   'connecticut',
#   "'",
#   's',
#   'first',
#   'constitution',
#   'called',
#   '?'],
#  ['what',
#   'historical',
#   'event',
#   'happened',
#   'in',
#   'dog',
#   '##town',
#   'in',
#   '1899',
#   '?'],
#  ['what', 'is', 'being', 'done', 'about', 'the', 'millennium', 'bug', '?'],
#  ['what',
#   'was',
#   'the',
#   'claim',
#   'to',
#   'fame',
#   'of',
#   'king',
#   'camp',
#   'gill',
#   '##ette',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'common',
#   'kind',
#   'of',
#   'skin',
#   'cancer',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   '?'],
#  ['what', 'is', 'ole', '##stra', '?'],
#  ['what',
#   'asian',
#   'country',
#   'has',
#   'a',
#   'bill',
#   'of',
#   'rights',
#   'for',
#   'cows',
#   '?'],
#  ['how', 'many', 'fingers', 'are', 'used', 'to', 'draw', 'a', 'bow', '?'],
#  ['what',
#   'are',
#   'two',
#   'plants',
#   'that',
#   'clothes',
#   'are',
#   'made',
#   'from',
#   '?'],
#  ['when', 'was', 'hurricane', 'hugo', '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'heavily',
#   'caf',
#   '##fe',
#   '##inated',
#   'soft',
#   'drink',
#   '?'],
#  ['what',
#   'president',
#   '-',
#   'to',
#   '-',
#   'be',
#   'was',
#   'the',
#   'first',
#   'member',
#   'of',
#   'congress',
#   'to',
#   'enlist',
#   'following',
#   'the',
#   'attack',
#   'on',
#   'pearl',
#   'harbor',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'price',
#   'of',
#   'var',
#   '##ian',
#   'associates',
#   "'",
#   'vacuum',
#   'products',
#   'division',
#   '?'],
#  ['when', 'was', '`', '`', 'the', 'great', 'depression', "'", "'", '?'],
#  ['what', 'language', 'is', 'mostly', 'spoken', 'in', 'brazil', '?'],
#  ['what',
#   'college',
#   'produced',
#   'the',
#   'most',
#   'winning',
#   'super',
#   'bowl',
#   'quarterback',
#   '##s',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'solve',
#   '`',
#   '`',
#   'rub',
#   '##ik',
#   "'",
#   's',
#   'cube',
#   "'",
#   "'",
#   '?'],
#  ['what', 'is', 'prepared', 'mustard', '?'],
#  ['what',
#   'classical',
#   'spanish',
#   'writer',
#   'warned',
#   ':',
#   '`',
#   '`',
#   'all',
#   'that',
#   'glitter',
#   '##s',
#   'is',
#   'not',
#   'gold',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'does',
#   '`',
#   '`',
#   'anti',
#   '##dis',
#   '##est',
#   '##ab',
#   '##lish',
#   '##ment',
#   '##arian',
#   '##ism',
#   "'",
#   "'",
#   'mean',
#   '?'],
#  ['what',
#   'actor',
#   'married',
#   'john',
#   'f',
#   '.',
#   'kennedy',
#   "'",
#   's',
#   'sister',
#   '?'],
#  ['what',
#   'does',
#   'a',
#   'top',
#   '##op',
#   '##ho',
#   '##bic',
#   'actor',
#   'suffer',
#   'from',
#   '?'],
#  ['who',
#   'fired',
#   'maria',
#   'y',
#   '##bar',
#   '##ra',
#   'from',
#   'her',
#   'position',
#   'in',
#   'san',
#   'diego',
#   'council',
#   '?'],
#  ['the',
#   'italian',
#   'artist',
#   ',',
#   'ma',
#   '##uri',
#   '##zio',
#   'pe',
#   '##lle',
#   '##grin',
#   ',',
#   'is',
#   'how',
#   'old',
#   '?'],
#  ['what',
#   'type',
#   'of',
#   'hunting',
#   'are',
#   'retrieve',
#   '##rs',
#   'used',
#   'for',
#   '?'],
#  ['what', 'is', 'colin', 'powell', 'best', 'known', 'for', '?'],
#  ['who',
#   'was',
#   'the',
#   'first',
#   'black',
#   'golfer',
#   'to',
#   'tee',
#   'off',
#   'in',
#   'the',
#   'masters',
#   '?'],
#  ['what',
#   'city',
#   'is',
#   'the',
#   'setting',
#   'for',
#   'pu',
#   '##cci',
#   '##ni',
#   "'",
#   's',
#   'opera',
#   'la',
#   'bo',
#   '##hem',
#   '##e',
#   '?'],
#  ['what',
#   'u',
#   '.',
#   's',
#   '.',
#   'president',
#   'showed',
#   'a',
#   'fond',
#   '##ness',
#   'for',
#   'mu',
#   '##nch',
#   '##ing',
#   'on',
#   'bee',
#   'pollen',
#   'bars',
#   '?'],
#  ['what', 'is', 'measured', 'in', 'cu', '##ries', '?'],
#  ['whose',
#   'cover',
#   'is',
#   'that',
#   'of',
#   'an',
#   'employee',
#   'of',
#   'universal',
#   'import',
#   'and',
#   'export',
#   '?'],
#  ['what',
#   'former',
#   'president',
#   "'",
#   's',
#   'daughter',
#   'has',
#   'written',
#   'a',
#   'book',
#   'titled',
#   'murder',
#   'in',
#   'the',
#   'white',
#   'house',
#   '?'],
#  ['what',
#   'fictional',
#   'character',
#   'is',
#   'known',
#   'as',
#   'the',
#   '`',
#   '`',
#   'melancholy',
#   'dane',
#   "'",
#   "'",
#   '?'],
#  ['italy', 'is', 'the', 'largest', 'producer', 'of', 'what', '?'],
#  ['what',
#   'longtime',
#   'game',
#   'show',
#   'host',
#   'dropped',
#   'dead',
#   'while',
#   'jogging',
#   'in',
#   'central',
#   'park',
#   'in',
#   '1984',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'meaning',
#   'of',
#   'w',
#   '.',
#   'b',
#   '.',
#   'ye',
#   '##at',
#   "'",
#   's',
#   'poem',
#   ',',
#   '`',
#   '`',
#   'the',
#   'three',
#   'hermit',
#   '##s',
#   '?',
#   "'",
#   "'"],
#  ['who',
#   'were',
#   'the',
#   '`',
#   '`',
#   'fi',
#   '##lth',
#   '##iest',
#   'people',
#   'alive',
#   '?',
#   "'",
#   "'"],
#  ['what',
#   'infectious',
#   'disease',
#   'is',
#   'the',
#   'world',
#   "'",
#   's',
#   'dead',
#   '##liest',
#   '?'],
#  ['what', 'is', 'sp', '##uman', '##te', '?'],
#  ['in',
#   'what',
#   'year',
#   'did',
#   'ireland',
#   'elect',
#   'its',
#   'first',
#   'woman',
#   'president',
#   '?'],
#  ['what', 'is', 'an', 'ist', '##hm', '##us', '?'],
#  ['what',
#   'was',
#   'the',
#   'name',
#   'of',
#   'the',
#   'or',
#   '##ca',
#   'that',
#   'died',
#   'of',
#   'a',
#   'fungal',
#   'infection',
#   '?'],
#  ['where', 'is', 'mozambique', 'located', '?'],
#  ['what', 'is', 'mississippi', "'", 's', 'state', 'animal', '?'],
#  ['what',
#   "'",
#   's',
#   'the',
#   'origin',
#   'of',
#   'the',
#   'word',
#   '`',
#   'news',
#   "'",
#   '?'],
#  ['what',
#   'did',
#   'dan',
#   'a',
#   '##yk',
#   '##roy',
#   '##d',
#   'and',
#   'john',
#   'bel',
#   '##ush',
#   '##i',
#   'quit',
#   'saturday',
#   'night',
#   'live',
#   'to',
#   'become',
#   '?'],
#  ['how',
#   'many',
#   'months',
#   'does',
#   'a',
#   'normal',
#   'human',
#   'pregnancy',
#   'last',
#   '?'],
#  ['how', 'do', 'fuel', 'in', '##ject', '##ors', 'work', '?'],
#  ['how',
#   'can',
#   'your',
#   'school',
#   'march',
#   'in',
#   'the',
#   'macy',
#   "'",
#   's',
#   'thanksgiving',
#   'parade',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'real',
#   'name',
#   'of',
#   'disc',
#   'jockey',
#   '`',
#   '`',
#   'wolf',
#   '##man',
#   'jack',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'italian',
#   'liner',
#   'was',
#   'hi',
#   '##jack',
#   '##ed',
#   'in',
#   '1985',
#   '?'],
#  ['what',
#   'city',
#   'houses',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'headquarters',
#   'of',
#   'pro',
#   '##cter',
#   'and',
#   'gamble',
#   '?'],
#  ['what',
#   'soap',
#   'was',
#   'to',
#   '##uted',
#   'as',
#   'being',
#   '`',
#   '`',
#   'for',
#   'people',
#   'who',
#   'like',
#   'people',
#   "'",
#   "'",
#   '?'],
#  ['how', 'much', 'was', 'the', 'minimum', 'wage', 'in', '1991', '?'],
#  ['what', 'does', 'na', '##ft', '##a', 'stand', 'for', '?'],
#  ['who', 'invented', 'silly', 'put', '##ty', '?'],
#  ['what',
#   'new',
#   'middle',
#   'school',
#   'was',
#   'built',
#   'in',
#   'philadelphia',
#   ',',
#   'pennsylvania',
#   'last',
#   'year',
#   '?'],
#  ['who', 'patented', 'the', 'first', 'ph', '##ono', '##graph', '?'],
#  ['what',
#   'are',
#   'some',
#   'tips',
#   'for',
#   'building',
#   'a',
#   'fire',
#   'in',
#   'a',
#   'fireplace',
#   '?'],
#  ['what', 'do', 'mana', '##tees', 'eat', '?'],
#  ['how', 'do', 'you', 'say', '2', 'in', 'latin', '?'],
#  ['what',
#   'were',
#   'popular',
#   'songs',
#   'and',
#   'types',
#   'of',
#   'songs',
#   'in',
#   'the',
#   '1920s',
#   '?'],
#  ['how',
#   'many',
#   'vietnamese',
#   'were',
#   'there',
#   'in',
#   'the',
#   'soviet',
#   'union',
#   '?'],
#  ['what', 'is', 'november', "'", 's', 'births', '##tone', '?'],
#  ['what', 'is', 'a', 'certified', 'nurse', 'mid', '##wife', '?'],
#  ['on',
#   'average',
#   ',',
#   'how',
#   'many',
#   'miles',
#   'are',
#   'there',
#   'to',
#   'the',
#   'moon',
#   '?'],
#  ['who', 'created', 'private', 'detective', 'philip', 'mar', '##lowe', '?'],
#  ['what',
#   'boris',
#   'paste',
#   '##rna',
#   '##k',
#   'book',
#   'sold',
#   '5',
#   ',',
#   '0',
#   'copies',
#   'to',
#   'become',
#   'the',
#   'fiction',
#   'best',
#   '-',
#   'seller',
#   'of',
#   '1958',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'origin',
#   'of',
#   'the',
#   'expression',
#   '`',
#   '`',
#   'to',
#   '##ut',
#   'de',
#   'suite',
#   "'",
#   "'",
#   '?'],
#  ['what', 'is', 'the', 'longest', 'english', 'word', '?'],
#  ['what', 'is', 'the', 'purpose', 'of', 'a', 'car', 'bra', '?'],
#  ['what', 'is', 'd', '.', 'b', '.', 'cooper', 'known', 'for', '?'],
#  ['who', 'is', 'colin', 'powell', '?'],
#  ['what', 'species', 'is', 'a', 'colt', '?'],
#  ['what', 'is', 'the', 'full', 'name', 'of', 'the', 'pl', '##o', '?'],
#  ['what', 'is', 'the', 'smallest', 'country', 'in', 'africa', '?'],
#  ['who',
#   'coined',
#   'the',
#   'term',
#   'n',
#   '##n',
#   'cyber',
#   '##space',
#   '`',
#   '`',
#   'in',
#   'his',
#   'novel',
#   'n',
#   '##n',
#   'ne',
#   '##uro',
#   '##man',
#   '##cer',
#   "'",
#   "'",
#   '?'],
#  ['what', 'age', 'followed', 'the', 'bronze', 'age', '?'],
#  ['what', 'is', 'her', 'profession', '?'],
#  ['what',
#   'is',
#   'the',
#   'full',
#   'name',
#   'of',
#   'the',
#   'man',
#   'who',
#   'invented',
#   'the',
#   'multi',
#   '##color',
#   '##ed',
#   'game',
#   'cube',
#   'that',
#   'has',
#   '42',
#   '.',
#   '3',
#   'qui',
#   '##nti',
#   '##lli',
#   '##on',
#   'potential',
#   'combinations',
#   '?'],
#  ['what', 'does', 'the', 'word', 'laser', 'mean', '?'],
#  ['what', 'does', 'the', 'name', '`', '`', 'anthony', "'", "'", 'mean', '?'],
#  ['who',
#   'was',
#   'lauren',
#   'ba',
#   '##cal',
#   '##l',
#   "'",
#   's',
#   'first',
#   'husband',
#   '?'],
#  ['what', 'is', 'a', 'r', '##hom', '##bo', '##ide', '##us', 'minor', '?'],
#  ['how',
#   'many',
#   'hands',
#   'does',
#   'bjorn',
#   'borg',
#   'use',
#   'when',
#   'hitting',
#   'his',
#   'fore',
#   '##hand',
#   '?'],
#  ['how', 'many', 'people', 'died', 'on', 'd', '-', 'day', '?'],
#  ['what',
#   'u',
#   '.',
#   's',
#   '.',
#   'congressman',
#   'said',
#   ':',
#   '`',
#   '`',
#   'keep',
#   'the',
#   'faith',
#   ',',
#   'baby',
#   "'",
#   "'",
#   '.'],
#  ['who', 'created', 'the', 'character', 'of', 'sc', '##ro', '##oge', '?'],
#  ['what',
#   'is',
#   'the',
#   'student',
#   'population',
#   'at',
#   'the',
#   'university',
#   'of',
#   'massachusetts',
#   'in',
#   'amherst',
#   '?'],
#  ['where', 'is', 'windsor', 'castle', '?'],
#  ['when', 'did', 'the', 'dow', 'first', 'reach', '?'],
#  ['why', 'were', 'people', 'recruited', 'for', 'the', 'vietnam', 'war', '?'],
#  ['what', 'party', 'was', 'winston', 'churchill', 'a', 'member', 'of', '?'],
#  ['what',
#   'american',
#   'league',
#   'baseball',
#   'team',
#   "'",
#   's',
#   'worst',
#   'finish',
#   'between',
#   '1926',
#   'and',
#   '1964',
#   'was',
#   'fourth',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'the',
#   'names',
#   'of',
#   'all',
#   'the',
#   '15',
#   'pokemon',
#   '?'],
#  ['what', 'state', 'does', 'martha', 'stewart', 'live', 'in', '?'],
#  ['which',
#   'killer',
#   'whale',
#   'died',
#   'at',
#   'sea',
#   'world',
#   'of',
#   'a',
#   'fungal',
#   'infection',
#   '?'],
#  ['what', 'are', 'the', 'ben', '##el', '##ux', 'countries', '?'],
#  ['where', "'", 's', 'the', 'pet', '##rified', 'forest', '?'],
#  ['what', 'is', 'a', 'language', 'spoken', 'by', 'the', 'sioux', '?'],
#  ['where', 'is', 'tornado', 'alley', '?'],
#  ['who',
#   'was',
#   'the',
#   'author',
#   'of',
#   '`',
#   '`',
#   'john',
#   'brown',
#   "'",
#   's',
#   'body',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'american',
#   'poet',
#   'wrote',
#   ':',
#   '`',
#   '`',
#   'good',
#   'fences',
#   'make',
#   'good',
#   'neighbors',
#   "'",
#   "'",
#   '?'],
#  ['what',
#   'state',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'has',
#   'the',
#   'most',
#   'blacks',
#   '?'],
#  ['why',
#   'are',
#   'electric',
#   'cars',
#   'less',
#   'efficient',
#   'in',
#   'the',
#   'northeast',
#   'than',
#   'in',
#   'california',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'occupation',
#   'of',
#   'mandy',
#   'rice',
#   '-',
#   'davies',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'city',
#   'in',
#   'which',
#   'ma',
#   '##uri',
#   '##zio',
#   'pe',
#   '##lle',
#   '##grin',
#   'lives',
#   'called',
#   '?'],
#  ['who', 'painted', 'the', 'sis', '##tine', 'chapel', '?'],
#  ['name',
#   'the',
#   'various',
#   'costume',
#   '##d',
#   'persona',
#   '##s',
#   'of',
#   'dr',
#   '.',
#   'henry',
#   'p',
#   '##ym',
#   '.'],
#  ['what',
#   'breed',
#   'of',
#   'dog',
#   'was',
#   'the',
#   '`',
#   '`',
#   'little',
#   'ras',
#   '##cal',
#   '##s',
#   "'",
#   "'",
#   'dog',
#   '?'],
#  ['what', 'are', 'the', 'living', 'conditions', 'in', 'cuba', '?'],
#  ['what', 'color', 'are', 'school', 'buses', '?'],
#  ['what', 'is', 'the', 'oldest', 'website', 'on', 'the', 'internet', '?'],
#  ['what', 'events', 'happened', 'january', '26', ',', '1978', '?'],
#  ['what', 'explorers', 'followed', 'columbus', 'to', 'the', 'americas', '?'],
#  ['who',
#   'is',
#   'actress',
#   'gold',
#   '##ie',
#   'ha',
#   '##wn',
#   "'",
#   's',
#   'current',
#   'actor',
#   'boyfriend',
#   '?'],
#  ['who',
#   'banned',
#   'peter',
#   'rose',
#   'from',
#   'baseball',
#   'for',
#   'betting',
#   'on',
#   'games',
#   '?'],
#  ['what', 'are', 'the', 'seven', 'virtues', '?'],
#  ['what',
#   'other',
#   'name',
#   'were',
#   'the',
#   '`',
#   '`',
#   'little',
#   'ras',
#   '##cal',
#   '##s',
#   "'",
#   "'",
#   'known',
#   'as',
#   '?'],
#  ['when', 'was', 'the', 'san', 'francisco', 'fire', '?'],
#  ['what', 'is', 'a', 'fear', 'of', 'food', '?'],
#  ['how', 'many', 'casinos', 'are', 'in', 'atlantic', 'city', ',', 'nj', '?'],
#  ...]
